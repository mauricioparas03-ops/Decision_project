# %%
country= input()
visits= int(input())
lists_of_cities=eval(input())



def add_new_country(name,times_visited, lists_of_cities_visited):
    new_country={}
    new_country["country"]=name
    new_country["visits"]=times_visited
    new_country["cities"]=lists_of_cities_visited
    travel_log.append(new_country)


add_new_country(country,visits,lists_of_cities)

print("something")
# Out:
#   Cell In[11], line 12
#     //travel_log.append(new_country)
#     ^
# SyntaxError: invalid syntax
